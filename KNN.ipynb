# %% [markdown]
# ## K-Means

# %% [markdown]
# Importo las dependencias

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets._samples_generator import make_blobs

# %% [markdown]
# Genero una distribución de 4 clusters, sin etiquetas.

# %%
X, y_true = make_blobs(n_samples=400, centers=4,
                       cluster_std=0.60, random_state=0)
X = X[:, ::-1] # flip axes for better plotting
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# Si a este dataset yo le aplico K-Means me va a formar clusters de acorde al valor K, es decir yo le digo al algorítmo de este distribución busca la mejor agrupación de 4 elementos. K-Means es aprendizaje NO supervizado ya que no se le asinga ninguna etiqueta a los datos. Justamente la idea del algorítmo es poder realizar esas etiquetas.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
# c:\Users\matia\anaconda3\envs\IA\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\matia\anaconda3\envs\IA\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# El punto en el centro de cada cluster representa el valor medio convergente de los 4 clusters que le indicamos. Con ese valor medio se calcula un radio en el que se incluye a los elemntos del cluster.

# %% [markdown]
# ### Referencias
#
# - (https://scikit-learn.org/stable/modules/clustering.html#k-means)[From SciKit docs]
# - https://jakevdp.github.io/PythonDataScienceHandbook/05.11-k-means.html
# - https://dhirajkumarblog.medium.com/difference-between-k-nearest-neighbor-k-nn-and-k-means-clustering-d9a44859182f#:~:text=K%2DNN%20is%20a%20classification,not%20have%20a%20training%20phase.
